# %% [markdown]
# # Import Library

# %%
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    precision_recall_curve,
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    roc_curve,
    auc,
)
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.discriminant_analysis import StandardScaler
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import clear_output
import warnings
from lazypredict.Supervised import LazyClassifier

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load the CSV file

# %%
# Load the data
data = pd.read_csv("dataset/data.csv")
df = pd.DataFrame(data.drop(["ID"], axis=1))

df.head()
# Out:
#    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0       5160         0.00        120.80           86.85               957
# 1      51980         0.00        115.32           83.45              1694
# 2       2600         0.00        229.93          172.76              2333
# 3       2130         0.00        369.40          183.19              1756
# 4       2310         0.00        258.00          111.28               987
#
#    max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0              6601              0.36                0.22      103.83
# 1              6998              0.27                0.14       99.38
# 2              5802              0.39                0.18      201.35
# 3              8159              0.56                0.16      276.30
# 4              4732              0.27                0.15      184.64
#
#    mean_jerk_in_air1  ...  mean_jerk_in_air25  mean_jerk_on_paper25  \
# 0               0.05  ...                0.14                  0.02
# 1               0.04  ...                0.05                  0.02
# 2               0.06  ...                0.18                  0.02
# 3               0.09  ...                0.11                  0.02
# 4               0.04  ...                0.12                  0.02
#
#    mean_speed_in_air25  mean_speed_on_paper25  num_of_pendown25  paper_time25  \
# 0                 5.60                   3.18                71         40120
# 1                 1.67                   0.95               129        126700
# 2                 4.00                   2.39                74         45480
# 3                 4.21                   1.61               123         67945
# 4                 3.32                   1.68                92         37285
#
#    pressure_mean25  pressure_var25  total_time25  class
# 0          1749.28       296102.77        144605      P
# 1          1504.77       278744.28        298640      P
# 2          1431.44       144411.71         79025      P
# 3          1465.84       230184.72        181220      P
# 4          1841.70       158290.03         72575      P

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Convert categorical value to numerical value

# %%
encoder = LabelEncoder()
df["class_encoded"] = encoder.fit_transform(df["class"])
df = df.drop(["class"], axis=1)

df.head()
# Out:
#    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0       5160         0.00        120.80           86.85               957
# 1      51980         0.00        115.32           83.45              1694
# 2       2600         0.00        229.93          172.76              2333
# 3       2130         0.00        369.40          183.19              1756
# 4       2310         0.00        258.00          111.28               987
#
#    max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0              6601              0.36                0.22      103.83
# 1              6998              0.27                0.14       99.38
# 2              5802              0.39                0.18      201.35
# 3              8159              0.56                0.16      276.30
# 4              4732              0.27                0.15      184.64
#
#    mean_jerk_in_air1  ...  mean_jerk_in_air25  mean_jerk_on_paper25  \
# 0               0.05  ...                0.14                  0.02
# 1               0.04  ...                0.05                  0.02
# 2               0.06  ...                0.18                  0.02
# 3               0.09  ...                0.11                  0.02
# 4               0.04  ...                0.12                  0.02
#
#    mean_speed_in_air25  mean_speed_on_paper25  num_of_pendown25  paper_time25  \
# 0                 5.60                   3.18                71         40120
# 1                 1.67                   0.95               129        126700
# 2                 4.00                   2.39                74         45480
# 3                 4.21                   1.61               123         67945
# 4                 3.32                   1.68                92         37285
#
#    pressure_mean25  pressure_var25  total_time25  class_encoded
# 0          1749.28       296102.77        144605              1
# 1          1504.77       278744.28        298640              1
# 2          1431.44       144411.71         79025              1
# 3          1465.84       230184.72        181220              1
# 4          1841.70       158290.03         72575              1

# %% [markdown]
# ## Features and target

# %%
# Independent (X) and Dependent (y) variable
X = df.drop(["class_encoded"], axis=1)
y = df["class_encoded"]

print(X, y)
# Out:
#      air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0         5160         0.00        120.80           86.85               957
# 1        51980         0.00        115.32           83.45              1694
# 2         2600         0.00        229.93          172.76              2333
# 3         2130         0.00        369.40          183.19              1756
# 4         2310         0.00        258.00          111.28               987
# ..         ...          ...           ...             ...               ...
# 169       2930         0.00        241.74          176.12              1839
# 170       2140         0.00        274.73          234.50              2053
# 171       3830         0.00        151.54          171.10              1287
# 172       1760         0.00        289.52          196.41              1674
# 173       2875         0.00        235.77          178.21              1838
#
#      max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0                6601              0.36                0.22      103.83
# 1                6998              0.27                0.14       99.38
# 2                5802              0.39                0.18      201.35
# 3                8159              0.56                0.16      276.30
# 4                4732              0.27                0.15      184.64
# ..                ...               ...                 ...         ...
# 169              6439              0.25                0.17      208.93
# 170              8487              0.23                0.17      254.61
# 171              7352              0.17                0.16      161.32
# 172              6946              0.52                0.20      242.96
# 173              6560              0.57                0.15      206.99
#
#      mean_jerk_in_air1  ...  mean_gmrt25  mean_jerk_in_air25  \
# 0                 0.05  ...       249.73                0.14
# 1                 0.04  ...        77.26                0.05
# 2                 0.06  ...       193.67                0.18
# 3                 0.09  ...       163.07                0.11
# 4                 0.04  ...       147.09                0.12
# ..                 ...  ...          ...                 ...
# 169               0.03  ...       200.57                0.12
# 170               0.03  ...       231.24                0.17
# 171               0.02  ...       177.94                0.11
# 172               0.09  ...       177.94                0.11
# 173               0.10  ...       177.94                0.11
#
#      mean_jerk_on_paper25  mean_speed_in_air25  mean_speed_on_paper25  \
# 0                    0.02                 5.60                   3.18
# 1                    0.02                 1.67                   0.95
# 2                    0.02                 4.00                   2.39
# 3                    0.02                 4.21                   1.61
# 4                    0.02                 3.32                   1.68
# ..                    ...                  ...                    ...
# 169                  0.02                 4.51                   2.23
# 170                  0.02                 4.69                   2.81
# 171                  0.02                 3.49                   2.51
# 172                  0.02                 3.49                   2.51
# 173                  0.02                 3.49                   2.51
#
#      num_of_pendown25  paper_time25  pressure_mean25  pressure_var25  \
# 0                  71         40120          1749.28       296102.77
# 1                 129        126700          1504.77       278744.28
# 2                  74         45480          1431.44       144411.71
# 3                 123         67945          1465.84       230184.72
# 4                  92         37285          1841.70       158290.03
# ..                ...           ...              ...             ...
# 169                96         44545          1798.92       247448.31
# 170                84         37560          1725.62       160664.65
# 171                88         51675          1915.57       128727.12
# 172                88         51675          1915.57       128727.12
# 173                88         51675          1915.57       128727.12
#
#      total_time25
# 0          144605
# 1          298640
# 2           79025
# 3          181220
# 4           72575
# ..            ...
# 169         80335
# 170        345835
# 171         83445
# 172         83445
# 173         83445   0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 169    0
# 170    0
# 171    0
# 172    0
# 173    0
# Name: class_encoded, dtype: int32

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data Summary

# %%
print("There are {} missing values in the data.".format(df.isna().sum().sum()))
# Out:
# There are 0 missing values in the data.

# %%
print("Data Summary:")
df.head()
# Out:
# Data Summary:
#    air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# 0       5160         0.00        120.80           86.85               957
# 1      51980         0.00        115.32           83.45              1694
# 2       2600         0.00        229.93          172.76              2333
# 3       2130         0.00        369.40          183.19              1756
# 4       2310         0.00        258.00          111.28               987
#
#    max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# 0              6601              0.36                0.22      103.83
# 1              6998              0.27                0.14       99.38
# 2              5802              0.39                0.18      201.35
# 3              8159              0.56                0.16      276.30
# 4              4732              0.27                0.15      184.64
#
#    mean_jerk_in_air1  ...  mean_jerk_in_air25  mean_jerk_on_paper25  \
# 0               0.05  ...                0.14                  0.02
# 1               0.04  ...                0.05                  0.02
# 2               0.06  ...                0.18                  0.02
# 3               0.09  ...                0.11                  0.02
# 4               0.04  ...                0.12                  0.02
#
#    mean_speed_in_air25  mean_speed_on_paper25  num_of_pendown25  paper_time25  \
# 0                 5.60                   3.18                71         40120
# 1                 1.67                   0.95               129        126700
# 2                 4.00                   2.39                74         45480
# 3                 4.21                   1.61               123         67945
# 4                 3.32                   1.68                92         37285
#
#    pressure_mean25  pressure_var25  total_time25  class_encoded
# 0          1749.28       296102.77        144605              1
# 1          1504.77       278744.28        298640              1
# 2          1431.44       144411.71         79025              1
# 3          1465.84       230184.72        181220              1
# 4          1841.70       158290.03         72575              1

# %%
print("Data Info:")
df.info()
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Columns: 451 entries, air_time1 to class_encoded
# dtypes: float64(300), int32(1), int64(150)
# memory usage: 612.5 KB

# %%
print("Data Statistics:")
df.describe()
# Out:
# Data Statistics:
#        air_time1  disp_index1  gmrt_in_air1  gmrt_on_paper1  max_x_extension1  \
# count     174.00       174.00        174.00          174.00            174.00
# mean     5664.17         0.00        297.67          200.50           1977.97
# std     12653.77         0.00        183.94          111.63           1648.31
# min        65.00         0.00         28.73           29.94            754.00
# 25%      1697.50         0.00        174.15          136.52           1362.50
# 50%      2890.00         0.00        255.79          176.49           1681.00
# 75%      4931.25         0.00        358.92          234.05           2082.75
# max    109965.00         0.00       1168.33          865.21          18602.00
#
#        max_y_extension1  mean_acc_in_air1  mean_acc_on_paper1  mean_gmrt1  \
# count            174.00            174.00              174.00      174.00
# mean            7323.90              0.42                0.18      249.09
# std             2188.29              0.38                0.06      132.70
# min              561.00              0.07                0.10       41.20
# 25%             6124.00              0.22                0.15      161.14
# 50%             6975.50              0.28                0.16      224.45
# 75%             8298.50              0.44                0.19      294.39
# max            15783.00              2.77                0.63      836.78
#
#        mean_jerk_in_air1  ...  mean_jerk_in_air25  mean_jerk_on_paper25  \
# count             174.00  ...              174.00                174.00
# mean                0.07  ...                0.15                  0.02
# std                 0.07  ...                0.06                  0.00
# min                 0.01  ...                0.03                  0.01
# 25%                 0.03  ...                0.11                  0.02
# 50%                 0.04  ...                0.14                  0.02
# 75%                 0.07  ...                0.20                  0.02
# max                 0.54  ...                0.38                  0.03
#
#        mean_speed_in_air25  mean_speed_on_paper25  num_of_pendown25  \
# count               174.00                 174.00            174.00
# mean                  4.47                   2.87             85.84
# std                   1.50                   0.85             27.49
# min                   1.32                   0.95             32.00
# 25%                   3.49                   2.40             66.00
# 50%                   4.51                   2.83             81.00
# 75%                   5.21                   3.34            101.50
# max                  10.42                   5.60            209.00
#
#        paper_time25  pressure_mean25  pressure_var25  total_time25  \
# count        174.00           174.00          174.00        174.00
# mean       43109.71          1629.59       163061.77     164203.33
# std        19092.02           324.14        56845.61     496939.70
# min        15930.00           474.05        26984.93      29980.00
# 25%        32803.75          1499.11       120099.05      59175.00
# 50%        37312.50          1729.39       158236.77      76115.00
# 75%        46533.75          1865.63       200921.08     127542.50
# max       139575.00          1999.78       352981.85    5704200.00
#
#        class_encoded
# count         174.00
# mean            0.51
# std             0.50
# min             0.00
# 25%             0.00
# 50%             1.00
# 75%             1.00
# max             1.00

# %%
data.nunique()
# Out:
# ID                 174
# air_time1          165
# disp_index1        131
# gmrt_in_air1       174
# gmrt_on_paper1     174
#                   ...
# paper_time25       159
# pressure_mean25    161
# pressure_var25     161
# total_time25       161
# class                2
# dtype: int64

# %% [markdown]
# ## Calculate mean, median, and mode

# %%
# Calculate mean, median, and mode
mean_values = X.mean()
median_values = X.median()
mode_values = X.mode().iloc[0]

# %%
print("Mean values:")
mean_values
# Out:
# Mean values:
# air_time1            5664.17
# disp_index1             0.00
# gmrt_in_air1          297.67
# gmrt_on_paper1        200.50
# max_x_extension1     1977.97
#                       ...
# num_of_pendown25       85.84
# paper_time25        43109.71
# pressure_mean25      1629.59
# pressure_var25     163061.77
# total_time25       164203.33
# dtype: float64

# %%
print("Median values:")
median_values
# Out:
# Median values:
# air_time1            2890.00
# disp_index1             0.00
# gmrt_in_air1          255.79
# gmrt_on_paper1        176.49
# max_x_extension1     1681.00
#                       ...
# num_of_pendown25       81.00
# paper_time25        37312.50
# pressure_mean25      1729.39
# pressure_var25     158236.77
# total_time25        76115.00
# dtype: float64

# %%
print("Mode values:")
mode_values
# Out:
# Mode values:
# air_time1            465.00
# disp_index1            0.00
# gmrt_in_air1          28.73
# gmrt_on_paper1        29.94
# max_x_extension1    1035.00
#                      ...
# num_of_pendown25      60.00
# paper_time25       35920.00
# pressure_mean25     1929.30
# pressure_var25     94373.03
# total_time25       59175.00
# Name: 0, dtype: float64

# %% [markdown]
# ## Distribution of the target variable 'class_encoded'

# %%
# Distribution of the target variable 'class_encoded'
plt.figure(figsize=(8, 6))
sns.countplot(x="class_encoded", data=df)
plt.title("Distribution of class_encoded")
plt.xlabel("class_encoded")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Utility Function

# %%
def get_figure_size(n):
    _x = max(min(n - 10, 30), 10)
    _y = max(min(n - 15, 20), 6)
    
    return (_x, _y)

def sorting_model_key(item):
    return (
        item["sorted_value"]
    )

# %% [markdown]
# # Split dataset into Train-Test

# %%
# random_state = sorted_model_data_list[0]['random_state']
random_state = 123

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=random_state
)


# scaler = StandardScaler()
# _X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# X_train, X_test, y_train, y_test = train_test_split(
#     _X, y, test_size=0.2, random_state=random_state
# )

# %% [markdown]
# # Features Importance

# %%
# Initialize the random forest classifier
rf_classifier = RandomForestClassifier(random_state=random_state)

# Train the model
rf_classifier.fit(X_train, y_train)


# Calculate feature importance
importances = rf_classifier.feature_importances_
feature_names = X_train.columns

# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]

# Remove features with importance values of 0 from sorted indices
indices = [index for index in indices if importances[index] != 0]
importances = importances[indices]
feature_names = feature_names[indices]

# Max and min value of importances
max_importance_value = max(importances)
min_importance_value = min(importances)

print(f"Max value: {max_importance_value}")
print(f"Min value: {min_importance_value}")
print(f"Total Number of Feature Importances: {len(importances)}")

#  Plot feature importances
plt.figure(figsize=get_figure_size(len(importances)))
plt.title("Feature Importances")
plt.bar(range(len(indices)), importances, align="center")
plt.xticks(range(len(indices)), feature_names, rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Max value: 0.027958215167417207
# Min value: 4.093931198393649e-05
# Total Number of Feature Importances: 386

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Splitting the important features into 21 subset

# %%
increment = (max_importance_value - min_importance_value) / 20

value_range = np.arange(
    min_importance_value, max_importance_value + increment, increment
)

# Create pairs of consecutive values using list comprehension
pairs_of_values = [[value, max_importance_value] for value in value_range]

print(f"Difference Value: {increment}")
print(f"Value Range Length: {len(value_range)}")
print(f"Number paired value:")
pairs_of_values
# Out:
# Difference Value: 0.0013958637927716636
# Value Range Length: 21
# Number paired value:
# [[4.093931198393649e-05, 0.027958215167417207],
#  [0.0014368031047556002, 0.027958215167417207],
#  [0.0028326668975272636, 0.027958215167417207],
#  [0.004228530690298928, 0.027958215167417207],
#  [0.005624394483070591, 0.027958215167417207],
#  [0.007020258275842254, 0.027958215167417207],
#  [0.00841612206861392, 0.027958215167417207],
#  [0.009811985861385583, 0.027958215167417207],
#  [0.011207849654157246, 0.027958215167417207],
#  [0.01260371344692891, 0.027958215167417207],
#  [0.013999577239700573, 0.027958215167417207],
#  [0.015395441032472238, 0.027958215167417207],
#  [0.0167913048252439, 0.027958215167417207],
#  [0.018187168618015562, 0.027958215167417207],
#  [0.019583032410787227, 0.027958215167417207],
#  [0.02097889620355889, 0.027958215167417207],
#  [0.022374759996330554, 0.027958215167417207],
#  [0.02377062378910222, 0.027958215167417207],
#  [0.02516648758187388, 0.027958215167417207],
#  [0.026562351374645545, 0.027958215167417207],
#  [0.027958215167417207, 0.027958215167417207]]

# %% [markdown]
# # Select best model with fixed features

# %%
# Important features to dataframe
important_df = pd.DataFrame(
    importances, index=feature_names, columns=["Importance"]
)

best_model_with_features = []

for _min, _max in pairs_of_values:
    filtered_features = important_df[
        (important_df["Importance"] >= _min)
        & (important_df["Importance"] <= _max)
    ]

    filtered_features_indices = filtered_features.index.tolist()

    if len(filtered_features) < 2:
        continue

    print(f"Number of Features: {len(filtered_features)}\tRange: {_min} - {_max}")

    # Calculate the correlation matrix
    temp = filtered_features_indices
    temp.append("class_encoded")
    correlation_matrix = df[temp].corr()
    correlation_matrix_abs = correlation_matrix.abs()

    # identify highly correlated features
    upper_tri = correlation_matrix_abs.where(
        np.triu(np.ones(correlation_matrix_abs.shape), k=1).astype(np.bool_)
    )

    high_corr_features = [
        column for column in upper_tri.columns if any(upper_tri[column] >= 0.9)
    ]

    # Drop the highly correlated features
    low_features = df[filtered_features_indices].drop(columns=high_corr_features)
    low_features_corr = low_features.corr()

    print(
        f"Number of Features After reducing: {len(low_features_corr)}\tRange: {_min} - {_max}"
    )

    # Get the feature names within the specified range
    selected_features = low_features.drop("class_encoded", axis=1).columns

    # Train a new model using only the selected features
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]

    clf = LazyClassifier(
        verbose=0,
        ignore_warnings=True,
        custom_metric=None,
        random_state=random_state,
    )

    models, predictions = clf.fit(X_train_selected, X_test_selected, y_train, y_test)

    # print("Best Model:")
    # print(models.iloc[0])
    # print("Best Prediction:")
    # print(predictions.iloc[0])

    best_model_with_features.append(
        {
            "model_name": models.iloc[0].name,
            "model_accuracy": models.iloc[0]["Accuracy"],
            "model_balance_accuracy": models.iloc[0]["Balanced Accuracy"],
            "model_roc_auc": models.iloc[0]["ROC AUC"],
            "model_f1_score": models.iloc[0]["F1 Score"],

            "prediction_accuracy": predictions.iloc[0]["Accuracy"],
            "prediction_balance_accuracy": predictions.iloc[0]["Balanced Accuracy"],
            "prediction_roc_auc": predictions.iloc[0]["ROC AUC"],
            "prediction_f1_score": predictions.iloc[0]["F1 Score"],
            
            "sorted_value": abs(
                models.iloc[0]["Accuracy"]
                + models.iloc[0]["Balanced Accuracy"]
                + models.iloc[0]["ROC AUC"]
                + models.iloc[0]["F1 Score"]
                - len(selected_features)
            ),

            "feature_length": len(selected_features),
            "features": selected_features,
        }
    )

    clear_output()


best_model_with_features
# Out:
# [{'model_name': 'AdaBoostClassifier',
#   'model_accuracy': 0.9428571428571428,
#   'model_balance_accuracy': 0.9337121212121212,
#   'model_roc_auc': 0.9337121212121212,
#   'model_f1_score': 0.9428571428571428,
#   'prediction_accuracy': 0.9428571428571428,
#   'prediction_balance_accuracy': 0.9337121212121212,
#   'prediction_roc_auc': 0.9337121212121212,
#   'prediction_f1_score': 0.9428571428571428,
#   'sorted_value': 298.24686147186145,
#   'feature_length': 302,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7',
#          ...
#          'mean_speed_in_air2', 'mean_jerk_on_paper20', 'pressure_var23',
#          'pressure_var25', 'max_x_extension1', 'mean_jerk_on_paper6',
#          'max_x_extension5', 'disp_index21', 'mean_acc_on_paper23',
#          'max_y_extension11'],
#         dtype='object', length=302)},
#  {'model_name': 'ExtraTreesClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8920454545454546,
#   'model_roc_auc': 0.8920454545454545,
#   'model_f1_score': 0.8879917184265009,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8920454545454546,
#   'prediction_roc_auc': 0.8920454545454545,
#   'prediction_f1_score': 0.8879917184265009,
#   'sorted_value': 143.4422030867683,
#   'feature_length': 147,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7',
#          ...
#          'mean_gmrt18', 'mean_speed_in_air1', 'pressure_var13', 'pressure_var3',
#          'pressure_mean19', 'num_of_pendown23', 'paper_time6',
#          'mean_speed_in_air12', 'pressure_mean11', 'mean_speed_on_paper11'],
#         dtype='object', length=147)},
#  {'model_name': 'ExtraTreesClassifier',
#   'model_accuracy': 0.9142857142857143,
#   'model_balance_accuracy': 0.9128787878787878,
#   'model_roc_auc': 0.9128787878787878,
#   'model_f1_score': 0.9152372142196378,
#   'prediction_accuracy': 0.9142857142857143,
#   'prediction_balance_accuracy': 0.9128787878787878,
#   'prediction_roc_auc': 0.9128787878787878,
#   'prediction_f1_score': 0.9152372142196378,
#   'sorted_value': 61.344719495737074,
#   'feature_length': 65,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13',
#          'paper_time22', 'gmrt_in_air7', 'total_time8', 'mean_speed_in_air25',
#          'mean_acc_on_paper21', 'pressure_mean4', 'pressure_mean5', 'air_time2',
#          'num_of_pendown19', 'gmrt_in_air23', 'disp_index20', 'total_time18',
#          'mean_speed_on_paper15', 'air_time5', 'total_time6', 'total_time7',
#          'pressure_mean8', 'mean_gmrt10', 'pressure_var19', 'total_time12',
#          'paper_time9', 'air_time11', 'mean_speed_in_air21', 'paper_time7',
#          'gmrt_on_paper10', 'mean_gmrt15', 'mean_speed_on_paper16',
#          'paper_time10', 'paper_time15', 'mean_jerk_on_paper3', 'total_time3',
#          'mean_speed_in_air19', 'pressure_mean21', 'disp_index17',
#          'pressure_mean3', 'mean_speed_on_paper9', 'pressure_mean16',
#          'mean_jerk_on_paper24', 'gmrt_on_paper20', 'air_time24',
#          'gmrt_on_paper23', 'pressure_mean20', 'max_y_extension21',
#          'mean_speed_on_paper2', 'gmrt_on_paper1', 'gmrt_in_air12',
#          'mean_speed_in_air14', 'mean_speed_on_paper12', 'max_y_extension19',
#          'mean_jerk_in_air25', 'paper_time13', 'max_x_extension21',
#          'pressure_mean7'],
#         dtype='object')},
#  {'model_name': 'RandomForestClassifier',
#   'model_accuracy': 0.8285714285714286,
#   'model_balance_accuracy': 0.8503787878787878,
#   'model_roc_auc': 0.850378787878788,
#   'model_f1_score': 0.8339660339660339,
#   'prediction_accuracy': 0.8285714285714286,
#   'prediction_balance_accuracy': 0.8503787878787878,
#   'prediction_roc_auc': 0.850378787878788,
#   'prediction_f1_score': 0.8339660339660339,
#   'sorted_value': 37.636704961704964,
#   'feature_length': 41,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13',
#          'paper_time22', 'gmrt_in_air7', 'total_time8', 'mean_speed_in_air25',
#          'mean_acc_on_paper21', 'pressure_mean4', 'pressure_mean5', 'air_time2',
#          'num_of_pendown19', 'gmrt_in_air23', 'disp_index20', 'total_time18',
#          'mean_speed_on_paper15', 'air_time5', 'total_time6', 'total_time7',
#          'pressure_mean8', 'mean_gmrt10', 'pressure_var19', 'total_time12',
#          'paper_time9', 'air_time11', 'mean_speed_in_air21', 'paper_time7',
#          'gmrt_on_paper10', 'mean_gmrt15', 'mean_speed_on_paper16',
#          'paper_time10', 'paper_time15'],
#         dtype='object')},
#  {'model_name': 'LGBMClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8920454545454546,
#   'model_roc_auc': 0.8920454545454545,
#   'model_f1_score': 0.8879917184265009,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8920454545454546,
#   'prediction_roc_auc': 0.8920454545454545,
#   'prediction_f1_score': 0.8879917184265009,
#   'sorted_value': 29.442203086768306,
#   'feature_length': 33,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13',
#          'paper_time22', 'gmrt_in_air7', 'total_time8', 'mean_speed_in_air25',
#          'mean_acc_on_paper21', 'pressure_mean4', 'pressure_mean5', 'air_time2',
#          'num_of_pendown19', 'gmrt_in_air23', 'disp_index20', 'total_time18',
#          'mean_speed_on_paper15', 'air_time5', 'total_time6', 'total_time7',
#          'pressure_mean8', 'mean_gmrt10', 'pressure_var19', 'total_time12',
#          'paper_time9'],
#         dtype='object')},
#  {'model_name': 'ExtraTreesClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8920454545454546,
#   'model_roc_auc': 0.8920454545454545,
#   'model_f1_score': 0.8879917184265009,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8920454545454546,
#   'prediction_roc_auc': 0.8920454545454545,
#   'prediction_f1_score': 0.8879917184265009,
#   'sorted_value': 24.442203086768306,
#   'feature_length': 28,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13',
#          'paper_time22', 'gmrt_in_air7', 'total_time8', 'mean_speed_in_air25',
#          'mean_acc_on_paper21', 'pressure_mean4', 'pressure_mean5', 'air_time2',
#          'num_of_pendown19', 'gmrt_in_air23', 'disp_index20', 'total_time18',
#          'mean_speed_on_paper15', 'air_time5', 'total_time6', 'total_time7'],
#         dtype='object')},
#  {'model_name': 'LGBMClassifier',
#   'model_accuracy': 0.9142857142857143,
#   'model_balance_accuracy': 0.9128787878787878,
#   'model_roc_auc': 0.9128787878787878,
#   'model_f1_score': 0.9152372142196378,
#   'prediction_accuracy': 0.9142857142857143,
#   'prediction_balance_accuracy': 0.9128787878787878,
#   'prediction_roc_auc': 0.9128787878787878,
#   'prediction_f1_score': 0.9152372142196378,
#   'sorted_value': 17.344719495737074,
#   'feature_length': 21,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13',
#          'paper_time22', 'gmrt_in_air7', 'total_time8', 'mean_speed_in_air25',
#          'mean_acc_on_paper21', 'pressure_mean4', 'pressure_mean5', 'air_time2',
#          'num_of_pendown19'],
#         dtype='object')},
#  {'model_name': 'Perceptron',
#   'model_accuracy': 0.8571428571428571,
#   'model_balance_accuracy': 0.8712121212121212,
#   'model_roc_auc': 0.8712121212121213,
#   'model_f1_score': 0.860952380952381,
#   'prediction_accuracy': 0.8571428571428571,
#   'prediction_balance_accuracy': 0.8712121212121212,
#   'prediction_roc_auc': 0.8712121212121213,
#   'prediction_f1_score': 0.860952380952381,
#   'sorted_value': 11.53948051948052,
#   'feature_length': 15,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13',
#          'paper_time22', 'gmrt_in_air7', 'total_time8'],
#         dtype='object')},
#  {'model_name': 'RandomForestClassifier',
#   'model_accuracy': 0.8571428571428571,
#   'model_balance_accuracy': 0.8465909090909092,
#   'model_roc_auc': 0.8465909090909092,
#   'model_f1_score': 0.8587286903660633,
#   'prediction_accuracy': 0.8571428571428571,
#   'prediction_balance_accuracy': 0.8465909090909092,
#   'prediction_roc_auc': 0.8465909090909092,
#   'prediction_f1_score': 0.8587286903660633,
#   'sorted_value': 8.590946634309262,
#   'feature_length': 12,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7', 'mean_speed_in_air17', 'total_time13'],
#         dtype='object')},
#  {'model_name': 'LGBMClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8674242424242424,
#   'model_roc_auc': 0.8674242424242424,
#   'model_f1_score': 0.8857142857142857,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8674242424242424,
#   'prediction_roc_auc': 0.8674242424242424,
#   'prediction_f1_score': 0.8857142857142857,
#   'sorted_value': 6.493722943722943,
#   'feature_length': 10,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7'],
#         dtype='object')},
#  {'model_name': 'LGBMClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8674242424242424,
#   'model_roc_auc': 0.8674242424242424,
#   'model_f1_score': 0.8857142857142857,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8674242424242424,
#   'prediction_roc_auc': 0.8674242424242424,
#   'prediction_f1_score': 0.8857142857142857,
#   'sorted_value': 6.493722943722943,
#   'feature_length': 10,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16', 'mean_gmrt7'],
#         dtype='object')},
#  {'model_name': 'SGDClassifier',
#   'model_accuracy': 0.8,
#   'model_balance_accuracy': 0.8295454545454546,
#   'model_roc_auc': 0.8295454545454546,
#   'model_f1_score': 0.8068906115417742,
#   'prediction_accuracy': 0.8,
#   'prediction_balance_accuracy': 0.8295454545454546,
#   'prediction_roc_auc': 0.8295454545454546,
#   'prediction_f1_score': 0.8068906115417742,
#   'sorted_value': 5.734018479367316,
#   'feature_length': 9,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17',
#          'air_time16'],
#         dtype='object')},
#  {'model_name': 'AdaBoostClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8674242424242424,
#   'model_roc_auc': 0.8674242424242424,
#   'model_f1_score': 0.8857142857142857,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8674242424242424,
#   'prediction_roc_auc': 0.8674242424242424,
#   'prediction_f1_score': 0.8857142857142857,
#   'sorted_value': 4.493722943722943,
#   'feature_length': 8,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17'],
#         dtype='object')},
#  {'model_name': 'AdaBoostClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8674242424242424,
#   'model_roc_auc': 0.8674242424242424,
#   'model_f1_score': 0.8857142857142857,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8674242424242424,
#   'prediction_roc_auc': 0.8674242424242424,
#   'prediction_f1_score': 0.8857142857142857,
#   'sorted_value': 4.493722943722943,
#   'feature_length': 8,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17', 'disp_index23', 'air_time22', 'paper_time17'],
#         dtype='object')},
#  {'model_name': 'LGBMClassifier',
#   'model_accuracy': 0.8857142857142857,
#   'model_balance_accuracy': 0.8920454545454546,
#   'model_roc_auc': 0.8920454545454545,
#   'model_f1_score': 0.8879917184265009,
#   'prediction_accuracy': 0.8857142857142857,
#   'prediction_balance_accuracy': 0.8920454545454546,
#   'prediction_roc_auc': 0.8920454545454545,
#   'prediction_f1_score': 0.8879917184265009,
#   'sorted_value': 1.4422030867683042,
#   'feature_length': 5,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23', 'total_time9',
#          'total_time17'],
#         dtype='object')},
#  {'model_name': 'XGBClassifier',
#   'model_accuracy': 0.8571428571428571,
#   'model_balance_accuracy': 0.8712121212121212,
#   'model_roc_auc': 0.8712121212121213,
#   'model_f1_score': 0.860952380952381,
#   'prediction_accuracy': 0.8571428571428571,
#   'prediction_balance_accuracy': 0.8712121212121212,
#   'prediction_roc_auc': 0.8712121212121213,
#   'prediction_f1_score': 0.860952380952381,
#   'sorted_value': 0.4605194805194808,
#   'feature_length': 3,
#   'features': Index(['paper_time23', 'air_time15', 'total_time23'], dtype='object')}]

# %% [markdown]
# ## Sort the model list with highest model, prediction value and lowest features

# %%
sorted_model_data_list = sorted(best_model_with_features, key=sorting_model_key)

sorted_model_data_list = [
    entry
    for entry in sorted_model_data_list
    if all(
        value >= 0.88
        for key, value in entry.items()
        if key.endswith("_accuracy")
        or key.endswith("_roc_auc")
        or key.endswith("_f1_score")
    )
]

pd.DataFrame(sorted_model_data_list, columns=["model_name", "feature_length", "model_accuracy", "prediction_accuracy"])
# sorted_model_data_list
# Out:
#              model_name  feature_length  model_accuracy  prediction_accuracy
# 0        LGBMClassifier               5            0.89                 0.89
# 1        LGBMClassifier              21            0.91                 0.91
# 2  ExtraTreesClassifier              28            0.89                 0.89
# 3        LGBMClassifier              33            0.89                 0.89
# 4  ExtraTreesClassifier              65            0.91                 0.91
# 5  ExtraTreesClassifier             147            0.89                 0.89
# 6    AdaBoostClassifier             302            0.94                 0.94

# %% [markdown]
# # Feature correlation and plotting

# %% [markdown]
# ## Correlation of best combination

# %%
best_model_features_list = list(sorted_model_data_list[0]['features'])
best_model_features_list.append("class_encoded")
correlation_matrix = df[best_model_features_list].corr()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=get_figure_size(len(best_model_features_list)))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title(f"Correlation Heatmap ({len(best_model_features_list)} feature)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model tuning and Scores

# %% [markdown]
# ## Model Tuning

# %% [markdown]
# ### Split data

# %%
lowest_features_name = list(sorted_model_data_list[0]["features"])

__X = X[lowest_features_name]
# scaler = StandardScaler()
# __X = pd.DataFrame(scaler.fit_transform(__X), columns=__X.columns)

__X_train, __X_test, __y_train, __y_test = train_test_split(
    __X, y, test_size=0.2, random_state=random_state
)

# %% [markdown]
# ### Check Lazypredict LGBM Model vs Our LGBM Accuracy

# %%
from lightgbm import LGBMClassifier


# Create the LGBMClassifier
lgbm = LGBMClassifier(random_state=random_state, verbose=-1)

# Train it
lgbm.fit(__X_train, __y_train)

# Prediction
__y_predict = lgbm.predict(__X_test)

# Calculate score
old_accuracy = accuracy_score(__y_test, __y_predict)
old_precision = precision_score(__y_test, __y_predict)
old_recall = recall_score(__y_test, __y_predict)
old_f1 = f1_score(__y_test, __y_predict)
old_classification_reports = classification_report(__y_test, __y_predict)

# Check Lazypredict accuracy == __y_predict accuracy
print(f"Lazypredict LGBM Model vs Our LGBM: {old_accuracy == sorted_model_data_list[0]['model_accuracy']}")
print(f"Our LGBM: \n{classification_report(__y_test, __y_predict)}")
old_accuracy
# Out:
# Lazypredict LGBM Model vs Our LGBM: True
# Our LGBM:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        24
#            1       0.77      0.91      0.83        11
#
#     accuracy                           0.89        35
#    macro avg       0.86      0.89      0.87        35
# weighted avg       0.90      0.89      0.89        35
# 0.8857142857142857

# %% [markdown]
# ### Grid Search

# %%
# Define the parameter grid for tuning
param_grid = {
    # 'n_estimators': list(range(20, 510, 10)),
    # 'max_depth': list(range(-1, 21, 1)),
    'n_estimators': [20, 30, 40, 50],
    'max_depth': [-1, 1, 2, 3],
}

# Create the LGBMClassifier
__lgbm = LGBMClassifier(random_state=random_state, verbose=-1)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=__lgbm, param_grid=param_grid, scoring="accuracy")

# Fit the model with the training data
grid_search.fit(X_train, y_train)

# clear_output()

# Print the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'max_depth': 3, 'n_estimators': 40}
# Best Score: 0.9208994708994709

# %%
# Get the best estimator
___lgbm = grid_search.best_estimator_

# Train it
___lgbm.fit(__X_train, __y_train)

# Prediction
___y_predict = ___lgbm.predict(__X_test)


print(f"LGBM: \n{classification_report(__y_test, ___y_predict)}")
# Out:
# LGBM:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85        24
#            1       0.67      0.73      0.70        11
#
#     accuracy                           0.80        35
#    macro avg       0.77      0.78      0.77        35
# weighted avg       0.81      0.80      0.80        35

# %% [markdown]
# ## Precision, Recall, F1 Score and Classification Report

# %%
accuracy = accuracy_score(__y_test, ___y_predict)
precision = precision_score(__y_test, ___y_predict)
recall = recall_score(__y_test, ___y_predict)
f1 = f1_score(__y_test, ___y_predict)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Classification Report:\n {classification_report(__y_test, ___y_predict)}")
# Out:
# Accuracy: 0.8
# Precision: 0.6666666666666666
# Recall: 0.7272727272727273
# F1 Score: 0.6956521739130435
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85        24
#            1       0.67      0.73      0.70        11
#
#     accuracy                           0.80        35
#    macro avg       0.77      0.78      0.77        35
# weighted avg       0.81      0.80      0.80        35

# %% [markdown]
# # Compare LazyPredict model vs tuning model

# %%
compare_table = pd.DataFrame({
    "Name": ["Old LGBM", "Tuning LGBM"],
    "Accuracy": [old_accuracy, accuracy],
    "Precision": [old_precision, precision],
    "Recall": [old_recall, recall],
    "F1 Score": [old_f1, f1],
})

compare_table
# Out:
#           Name  Accuracy  Precision  Recall  F1 Score
# 0     Old LGBM      0.89       0.77    0.91      0.83
# 1  Tuning LGBM      0.80       0.67    0.73      0.70

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Precision Recall Curve (Model)

# %%
precision, recall, _ = precision_recall_curve(__y_test, ___y_predict)

plt.figure(figsize=get_figure_size(len(precision)))
plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision-Recall Curve (Tuning LGBM)')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.show()

# %% [markdown]
# ## F1 Score Curve (Model)

# %%
f1_values = 2 * (precision * recall) / (precision + recall)

plt.figure(figsize=get_figure_size(len(precision)))
plt.plot(recall, f1_values, color='b', label='F1-score')
plt.xlabel('Recall')
plt.ylabel('F1-score')
plt.title('F1-score Curve (Tuning LGBM)')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.legend()
plt.show()

# %% [markdown]
# ## Confusion Matrix (Model)

# %%
confusion_mat = confusion_matrix(__y_test, ___y_predict)
plt.figure(figsize=get_figure_size(len(confusion_mat)))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix (Tuning LGBM)')
plt.show()

# %% [markdown]
# ## ROC AUC Curve (Model)

# %%
fpr, tpr, thresholds = roc_curve(__y_test, ___y_predict)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=get_figure_size(len(fpr)))
plt.plot(fpr, tpr, color='b', label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='r', linestyle='--')
plt.xlim([0, 1])
plt.ylim([0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve (Tuning Model)')
plt.legend(loc="lower right")
plt.show()
